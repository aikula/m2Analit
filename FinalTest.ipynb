# %% [markdown]
# # Финальное задание
#
# Провести анализ датасета. Сделать выводы:
# - Приоритетное привлечение: Сосредоточиться на сегментах пассажиров с высокой частотой поездок и высоким средним чеком.
# - Прибыльные пассажиры: Идентифицировать группы, которые приносят наибольший доход, и разработать стратегии их удержания и привлечения.
#
# ## Датасет
# `Final_test.xlsx`
#
# ## Закодированные поля
#
# Пол (gender):
# * 0 - Мужской
# * 1 - Женский
#
# Цель поездки (trip_purpose):
# * 1 - Деловая поездка
# * 2 - Личная поездка
# * 3 - Туризм
#
# Тип билета (ticket_type):
# * 1 - Плацкарт
# * 2 - Купе
# * 3 - СВ
# * 4 - Люкс
#
# Сезон (season):
# * 1 - Весна
# * 2 - Лето
# * 3 - Осень
# * 4 - Зима
#
# Канал покупки (purchase_channel):
# * 1 - Онлайн
# * 2 - Касса
# * 3 - Мобильное приложение
#
# Города (departure_city/arrival_city):
# * 1 - Москва
# * 2 - Санкт-Петербург
# * 3 - Нижний Новгород
# * 4 - Казань
# * 5 - Екатеринбург
#
# Метод оплаты (payment_method):
# * 1 - Наличные
# * 2 - Банковская карта
# * 3 - Электронный кошелек
#
# Уровень лояльности (loyalty_level):
# * 0 - Без программы лояльности
# * 1 - Базовый
# * 2 - Серебряный
# * 3 - Золотой
#
# Дополнительные услуги (additional_services):
# * 0 - Нет
# * 1 - Да
